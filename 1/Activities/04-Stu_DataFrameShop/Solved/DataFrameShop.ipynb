# %%
# Import Dependencies
import pandas as pd

# %%
# DataFrame should have 3 columns: Frame, Price, and Sales AND 5 rows of data
photos_df = pd.DataFrame(
    {"": [0,1, 2,3,4],
     "Frame": ["Ornate","Classical", "Mordern","Wood","Cardboard"],
     "Price": [15.0,12.5,10.0,5.0,1.0],
     "Sales": [100,200,150,300,"N/A"]
     }
)
photos_df
# Out:
#           Frame  Price Sales
# 0  0     Ornate   15.0   100
# 1  1  Classical   12.5   200
# 2  2    Mordern   10.0   150
# 3  3       Wood    5.0   300
# 4  4  Cardboard    1.0   N/A

# %%
# Use a different method of creating DataFrames to
# Create a DataFrame for an art gallery that contains three columns - "Painting", "Price", and "Popularity"
# and has 4 rows of data
printing_dicts = [ {"":0,"Printing":"Mona Lisa(Knockoff)","Popularity":"Very Popular","Price":25},
                  {"":1,"Printing":"Van Gogh(Knockoff)","Popularity":" Popular","Price":20},
            {"":2,"Printing":"Starving Artist","Popularity":" Average","Price":10},
            {"":3,"Printing":"Toddler Drawing","Popularity":" Not Popular","Price":1}]

printing_df = pd.DataFrame(printing_dicts)
printing_df
# Out:
#                  Printing    Popularity  Price
# 0  0  Mona Lisa(Knockoff)  Very Popular     25
# 1  1   Van Gogh(Knockoff)       Popular     20
# 2  2      Starving Artist       Average     10
# 3  3      Toddler Drawing   Not Popular      1
